# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 100
z = np.arange(n, dtype=float)
z *= 2.0*np.pi / float(n-1)
sin_z = np.sin(z)

# %%
plt.figure()
plt.plot(z, sin_z, c='m')
plt.xlabel('z')
plt.ylabel('sin(z)')
plt.show()
